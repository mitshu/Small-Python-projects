# %%
from  PIL import Image
import PIL.Image

from pytesseract import image_to_string
import pytesseract

# %%
img = Image.open('hoa_don.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=857x606 at 0x251914EEA90>

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
text = image_to_string(img)

# %%
lines = text.split('\n\n')

for line in lines:
    if line != " ":
        print(line)
#print(text)
# Out:
# HOA DON GTGT (TIEN BIEN) Mae Aes oa
# (Ban thé hién cua hoa don dién tte) S6: 047!
# Ky:1 Tir ngay: 201092018 Dénngay: 19/10/2018 ID HD: 66559)
# EVNSPC
# ‘TONG CONC TY pe UFC Abn NAIK
# Céng Ty Bién Lye Vinh Long - Bign Lye Ving Liem
# ja chi: $6 59 Nam Ky Khdi Nghia, khém 1, thi trén Ving Liém, huyén Viing Liém, tinh Vinh Long
# ign thoai: 19009000 MST: 0300942001.021 BT sia chiva: 19001006
# Ten khach hang:
# iia chi: Ap 1-x@ Trung Ngai- huyén Ving Liém - -
# Bin thoai: MST: S6 cng to: 07040 S6hO:4
# Ma KH: PB10050004 Ma T.toan: PB10050004! Ma NN: 4402 Ma t6:
# Ma tram: 100537950 Cap BA: 1 $6 GCS: £0519-010 PGCS:19
# Ma gid: KT: 100%"SHBT-A
# Bocs | CHisOmOI| CHisO6cU | HSNHAN DN TIEU THU DONGIA HANH TIEN
# KT 8.429 8.157 1 272
# 50 1.549 77.450
# 50 1.600 80,000
# 100 1858 185,800
# rR 2.340 168.480
# Cong 272 511.730
# Thué sudt GTGT: 10% Thué GTGT: 81.173
# Téng céng tién thanh toan: 562.903
# 86 tién viét béing chit Nam trém séu muoi hai nghin chin trém linh ba déng.
# ...
